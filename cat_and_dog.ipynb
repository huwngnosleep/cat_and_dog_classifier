# %%
import os
import sys
import scipy.io
import scipy.misc
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from sklearn.model_selection import train_test_split
from PIL import Image
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.python.framework.ops import EagerTensor
import pprint
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.python.framework.ops import EagerTensor
from matplotlib.pyplot import imshow
# %matplotlib inline

# %%
IMAGE_WIDTH=64
IMAGE_HEIGHT=64
IMAGE_SIZE=(IMAGE_WIDTH,IMAGE_HEIGHT)
IMAGE_CHANNEL=3
IMAGE_PATH = './pet_images'
BATCH_SIZE = 20
EPOCHS = 64
CLASSES = os.listdir(IMAGE_PATH)
NUM_CLASSES = len(CLASSES)

# %%
cat_image_dirs=os.listdir("./pet_images/Cat")
dog_image_dirs=os.listdir("./pet_images/Dog")
image_dirs = cat_image_dirs + dog_image_dirs

labels = list(map(lambda x: 'cat', cat_image_dirs)) + list(map(lambda x: 'dog', dog_image_dirs))
len(labels)
# Out:
# 24961

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    horizontal_flip=True,
    validation_split=0.2)

train_dataset = train_datagen.flow_from_directory(
    IMAGE_PATH,
    target_size = (IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size = BATCH_SIZE,
    subset = "training",
    class_mode = "categorical",
    shuffle = True
)

val_dataset = train_datagen.flow_from_directory(
    IMAGE_PATH,
    target_size = (IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size = BATCH_SIZE,
    subset = "validation",
    class_mode = "categorical",
    shuffle = True
)
# Out:
# Found 19968 images belonging to 2 classes.
# Found 4991 images belonging to 2 classes.

# %%
def identity_block(X, f, filters, training=True, initializer=random_uniform):
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = 1, strides = (1,1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training) # Default axis
    X = Activation('relu')(X)
    
    ### START CODE HERE
    ## Second component of main path (≈3 lines)
    ## Set the padding = 'same'
    X = Conv2D(filters = F2, kernel_size = f, strides = (1,1), padding = 'same', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training) # Default axis
    X = Activation('relu')(X)

    ## Third component of main path (≈2 lines)
    ## Set the padding = 'valid'
    X = Conv2D(filters = F3, kernel_size = 1, strides = (1,1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training) # Default axis
    
    ## Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X,X_shortcut])
    X = Activation('relu')(X)
    ### END CODE HERE
    return X

# %%
def convolutional_block(X, f, filters, s = 2, training=True, initializer=glorot_uniform):
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    
    # First component of main path glorot_uniform(seed=0)
    X = Conv2D(filters = F1, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    ### START CODE HERE
    
    ## Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = f, strides = (1, 1), padding='same', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    ## Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = 1, strides = (1, 1), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    
    ##### SHORTCUT PATH ##### (≈2 lines)
    X_shortcut = Conv2D(filters = F3, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3)(X_shortcut, training=training)
    
    ### END CODE HERE

    # Final step: Add shortcut value to main path (Use this order [X, X_shortcut]), and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def ResNet50(input_shape = (IMAGE_HEIGHT, IMAGE_WIDTH, 3), classes = 2):
    """
    Stage-wise implementation of the architecture of the popular ResNet50:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> FLATTEN -> DENSE 

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [IMAGE_HEIGHT, IMAGE_WIDTH, 256], s = 1)
    X = identity_block(X, 3, [IMAGE_HEIGHT, IMAGE_WIDTH, 256])
    X = identity_block(X, 3, [IMAGE_HEIGHT, IMAGE_WIDTH, 256])

    ### START CODE HERE
    
    ## Stage 3 (≈4 lines)
    X = convolutional_block(X, f = 3, filters = [IMAGE_HEIGHT * 2, IMAGE_WIDTH * 2,512], s = 2)
    X = identity_block(X, 3, [IMAGE_HEIGHT * 2, IMAGE_WIDTH * 2,512])
    X = identity_block(X, 3, [IMAGE_HEIGHT * 2, IMAGE_WIDTH * 2,512])
    X = identity_block(X, 3, [IMAGE_HEIGHT * 2, IMAGE_WIDTH * 2,512])
    
    ## Stage 4 (≈6 lines)
    X = convolutional_block(X, f = 3, filters = [IMAGE_HEIGHT * 4, IMAGE_WIDTH * 4, 1024], s = 2)
    X = identity_block(X, 3, [IMAGE_HEIGHT * 4, IMAGE_WIDTH * 4, 1024])
    X = identity_block(X, 3, [IMAGE_HEIGHT * 4, IMAGE_WIDTH * 4, 1024])
    X = identity_block(X, 3, [IMAGE_HEIGHT * 4, IMAGE_WIDTH * 4, 1024])
    X = identity_block(X, 3, [IMAGE_HEIGHT * 4, IMAGE_WIDTH * 4, 1024])
    X = identity_block(X, 3, [IMAGE_HEIGHT * 4, IMAGE_WIDTH * 4, 1024])

    ## Stage 5 (≈3 lines)
    X = convolutional_block(X, f = 3, filters = [IMAGE_HEIGHT * 8, IMAGE_WIDTH * 8, 2048], s = 2)
    X = identity_block(X, 3, [IMAGE_HEIGHT * 8, IMAGE_WIDTH * 8, 2048])
    X = identity_block(X, 3, [IMAGE_HEIGHT * 8, IMAGE_WIDTH * 8, 2048])

    ## AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    X = AveragePooling2D(pool_size=(2, 2))(X)
    
    ### END CODE HERE

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X)

    return model

# %%
model = ResNet50(input_shape = (IMAGE_HEIGHT, IMAGE_WIDTH, 3), classes = NUM_CLASSES)
print(model.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d_3 (ZeroPadding2  (None, 70, 70, 3)   0           ['input_4[0][0]']
#  D)
#
#  conv2d_159 (Conv2D)            (None, 32, 32, 64)   9472        ['zero_padding2d_3[0][0]']
#
#  batch_normalization_159 (Batch  (None, 32, 32, 64)  256         ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_159[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 15, 15, 64)  0           ['activation_147[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 15, 15, 64)   4160        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_160 (Batch  (None, 15, 15, 64)  256         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_160[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_148[0][0]']
#
#  batch_normalization_161 (Batch  (None, 15, 15, 64)  256         ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_161[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_149[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 15, 15, 256)  16640       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_162 (Batch  (None, 15, 15, 256)  1024       ['conv2d_162[0][0]']
#  Normalization)
#
#  batch_normalization_163 (Batch  (None, 15, 15, 256)  1024       ['conv2d_163[0][0]']
#  Normalization)
#
#  add_48 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_162[0][0]',
#                                                                   'batch_normalization_163[0][0]']
#
#  activation_150 (Activation)    (None, 15, 15, 256)  0           ['add_48[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_150[0][0]']
#
#  batch_normalization_164 (Batch  (None, 15, 15, 64)  256         ['conv2d_164[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_164[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_151[0][0]']
#
#  batch_normalization_165 (Batch  (None, 15, 15, 64)  256         ['conv2d_165[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_165[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_152[0][0]']
#
#  batch_normalization_166 (Batch  (None, 15, 15, 256)  1024       ['conv2d_166[0][0]']
#  Normalization)
#
#  add_49 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_166[0][0]',
#                                                                   'activation_150[0][0]']
#
#  activation_153 (Activation)    (None, 15, 15, 256)  0           ['add_49[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_153[0][0]']
#
#  batch_normalization_167 (Batch  (None, 15, 15, 64)  256         ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_167[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_154[0][0]']
#
#  batch_normalization_168 (Batch  (None, 15, 15, 64)  256         ['conv2d_168[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_168[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_155[0][0]']
#
#  batch_normalization_169 (Batch  (None, 15, 15, 256)  1024       ['conv2d_169[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_169[0][0]',
#                                                                   'activation_153[0][0]']
#
#  activation_156 (Activation)    (None, 15, 15, 256)  0           ['add_50[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 8, 8, 128)    32896       ['activation_156[0][0]']
#
#  batch_normalization_170 (Batch  (None, 8, 8, 128)   512         ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_170[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_157[0][0]']
#
#  batch_normalization_171 (Batch  (None, 8, 8, 128)   512         ['conv2d_171[0][0]']
#  Normalization)
#
#  activation_158 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_171[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_158[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 8, 8, 512)    131584      ['activation_156[0][0]']
#
#  batch_normalization_172 (Batch  (None, 8, 8, 512)   2048        ['conv2d_172[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 8, 8, 512)   2048        ['conv2d_173[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_172[0][0]',
#                                                                   'batch_normalization_173[0][0]']
#
#  activation_159 (Activation)    (None, 8, 8, 512)    0           ['add_51[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_159[0][0]']
#
#  batch_normalization_174 (Batch  (None, 8, 8, 128)   512         ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_160 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_174[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_160[0][0]']
#
#  batch_normalization_175 (Batch  (None, 8, 8, 128)   512         ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_161 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_175[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_161[0][0]']
#
#  batch_normalization_176 (Batch  (None, 8, 8, 512)   2048        ['conv2d_176[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_176[0][0]',
#                                                                   'activation_159[0][0]']
#
#  activation_162 (Activation)    (None, 8, 8, 512)    0           ['add_52[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_162[0][0]']
#
#  batch_normalization_177 (Batch  (None, 8, 8, 128)   512         ['conv2d_177[0][0]']
#  Normalization)
#
#  activation_163 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_177[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_163[0][0]']
#
#  batch_normalization_178 (Batch  (None, 8, 8, 128)   512         ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_164 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_178[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_164[0][0]']
#
#  batch_normalization_179 (Batch  (None, 8, 8, 512)   2048        ['conv2d_179[0][0]']
#  Normalization)
#  add_53 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_179[0][0]',
#                                                                   'activation_162[0][0]']
#
#  activation_165 (Activation)    (None, 8, 8, 512)    0           ['add_53[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 8, 8, 128)    65664       ['activation_165[0][0]']
#
#  batch_normalization_180 (Batch  (None, 8, 8, 128)   512         ['conv2d_180[0][0]']
#  Normalization)
#
#  activation_166 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_180[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 8, 8, 128)    147584      ['activation_166[0][0]']
#
#  batch_normalization_181 (Batch  (None, 8, 8, 128)   512         ['conv2d_181[0][0]']
#  Normalization)
#
#  activation_167 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_181[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 8, 8, 512)    66048       ['activation_167[0][0]']
#
#  batch_normalization_182 (Batch  (None, 8, 8, 512)   2048        ['conv2d_182[0][0]']
#  Normalization)
#
#  add_54 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_182[0][0]',
#                                                                   'activation_165[0][0]']
#
#  activation_168 (Activation)    (None, 8, 8, 512)    0           ['add_54[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 4, 4, 256)    131328      ['activation_168[0][0]']
#
#  batch_normalization_183 (Batch  (None, 4, 4, 256)   1024        ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_169 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_183[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_169[0][0]']
#
#  batch_normalization_184 (Batch  (None, 4, 4, 256)   1024        ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_184[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_170[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 4, 4, 1024)   525312      ['activation_168[0][0]']
#
#  batch_normalization_185 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_186[0][0]']
#  Normalization)
#
#  add_55 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_185[0][0]',
#                                                                   'batch_normalization_186[0][0]']
#
#  activation_171 (Activation)    (None, 4, 4, 1024)   0           ['add_55[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_171[0][0]']
#
#  batch_normalization_187 (Batch  (None, 4, 4, 256)   1024        ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_187[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_172[0][0]']
#
#  batch_normalization_188 (Batch  (None, 4, 4, 256)   1024        ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_173 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_188[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_173[0][0]']
#
#  batch_normalization_189 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_189[0][0]']
#  Normalization)
#
#  add_56 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_189[0][0]',
#                                                                   'activation_171[0][0]']
#
#  activation_174 (Activation)    (None, 4, 4, 1024)   0           ['add_56[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_174[0][0]']
#
#  batch_normalization_190 (Batch  (None, 4, 4, 256)   1024        ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_175 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_175[0][0]']
#
#  batch_normalization_191 (Batch  (None, 4, 4, 256)   1024        ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_176 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_176[0][0]']
#
#  batch_normalization_192 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_192[0][0]']
#  Normalization)
#
#  add_57 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_192[0][0]',
#                                                                   'activation_174[0][0]']
#
#  activation_177 (Activation)    (None, 4, 4, 1024)   0           ['add_57[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_177[0][0]']
#
#  batch_normalization_193 (Batch  (None, 4, 4, 256)   1024        ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_178 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_193[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_178[0][0]']
#
#  batch_normalization_194 (Batch  (None, 4, 4, 256)   1024        ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_194[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_179[0][0]']
#
#  batch_normalization_195 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_195[0][0]']
#  Normalization)
#
#  add_58 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_195[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_180 (Activation)    (None, 4, 4, 1024)   0           ['add_58[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_180[0][0]']
#
#  batch_normalization_196 (Batch  (None, 4, 4, 256)   1024        ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_181[0][0]']
#
#  batch_normalization_197 (Batch  (None, 4, 4, 256)   1024        ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_182 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_182[0][0]']
#
#  batch_normalization_198 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_198[0][0]']
#  Normalization)
#
#  add_59 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_198[0][0]',
#                                                                   'activation_180[0][0]']
#
#  activation_183 (Activation)    (None, 4, 4, 1024)   0           ['add_59[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 4, 4, 256)    262400      ['activation_183[0][0]']
#
#  batch_normalization_199 (Batch  (None, 4, 4, 256)   1024        ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_199[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 4, 4, 256)    590080      ['activation_184[0][0]']
#
#  batch_normalization_200 (Batch  (None, 4, 4, 256)   1024        ['conv2d_200[0][0]']
#  Normalization)
#  activation_185 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 4, 4, 1024)   263168      ['activation_185[0][0]']
#
#  batch_normalization_201 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_201[0][0]']
#  Normalization)
#
#  add_60 (Add)                   (None, 4, 4, 1024)   0           ['batch_normalization_201[0][0]',
#                                                                   'activation_183[0][0]']
#
#  activation_186 (Activation)    (None, 4, 4, 1024)   0           ['add_60[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 2, 2, 512)    524800      ['activation_186[0][0]']
#
#  batch_normalization_202 (Batch  (None, 2, 2, 512)   2048        ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_202[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_187[0][0]']
#
#  batch_normalization_203 (Batch  (None, 2, 2, 512)   2048        ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_203[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_188[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 2, 2, 2048)   2099200     ['activation_186[0][0]']
#
#  batch_normalization_204 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_204[0][0]']
#  Normalization)
#
#  batch_normalization_205 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_205[0][0]']
#  Normalization)
#
#  add_61 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_204[0][0]',
#                                                                   'batch_normalization_205[0][0]']
#
#  activation_189 (Activation)    (None, 2, 2, 2048)   0           ['add_61[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 2, 2, 512)    1049088     ['activation_189[0][0]']
#
#  batch_normalization_206 (Batch  (None, 2, 2, 512)   2048        ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_206[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_190[0][0]']
#
#  batch_normalization_207 (Batch  (None, 2, 2, 512)   2048        ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_207[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_191[0][0]']
#
#  batch_normalization_208 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_208[0][0]']
#  Normalization)
#
#  add_62 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_208[0][0]',
#                                                                   'activation_189[0][0]']
#
#  activation_192 (Activation)    (None, 2, 2, 2048)   0           ['add_62[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 2, 2, 512)    1049088     ['activation_192[0][0]']
#
#  batch_normalization_209 (Batch  (None, 2, 2, 512)   2048        ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_209[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 2, 2, 512)    2359808     ['activation_193[0][0]']
#
#  batch_normalization_210 (Batch  (None, 2, 2, 512)   2048        ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_210[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 2, 2, 2048)   1050624     ['activation_194[0][0]']
#
#  batch_normalization_211 (Batch  (None, 2, 2, 2048)  8192        ['conv2d_211[0][0]']
#  Normalization)
#
#  add_63 (Add)                   (None, 2, 2, 2048)   0           ['batch_normalization_211[0][0]',
#                                                                   'activation_192[0][0]']
#
#  activation_195 (Activation)    (None, 2, 2, 2048)   0           ['add_63[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 1, 1, 2048)  0           ['activation_195[0][0]']
#  oling2D)
#
#  flatten_3 (Flatten)            (None, 2048)         0           ['average_pooling2d_3[0][0]']
#
#  dense_3 (Dense)                (None, 2)            4098        ['flatten_3[0][0]']
#
# ==================================================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_dataset, validation_data = val_dataset, epochs = EPOCHS, batch_size = BATCH_SIZE)
# Out:
# Epoch 1/64
# 999/999 [==============================] - 1338s 1s/step - loss: 0.8384 - accuracy: 0.5997 - val_loss: 0.7205 - val_accuracy: 0.5444
# Epoch 2/64
# 999/999 [==============================] - 1291s 1s/step - loss: 0.6938 - accuracy: 0.6022 - val_loss: 0.6664 - val_accuracy: 0.6147
# Epoch 3/64
# 999/999 [==============================] - ETA: 0s - loss: 0.6405 - accuracy: 0.6548
